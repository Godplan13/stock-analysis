# %% [markdown]
# <a href="https://colab.research.google.com/github/Godplan13/stock-analysis/blob/main/George13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
2+3
# Out:
# 5

# %%
import math
math.sin(45)
# Out:
# 0.8509035245341184

# %%
import numpy as np # data analysis
import matplotlib as plt # data visualisation - ploting graph
import seaborn as sns # data visualisation - ploting graph
import yfinance as yf

# %%
! pip install yfinance

# %%
import yfinance as yf

# %%
start = '2020-01-01'
end = '2024-10-31'

# %%
NVDA =yf.download('NVDA', start, end)
NVDA
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                       Adj Close       Close        High         Low  \
# Ticker                           NVDA        NVDA        NVDA        NVDA
# Date
# 2020-01-02 00:00:00+00:00    5.973122    5.997750    5.997750    5.918000
# 2020-01-03 00:00:00+00:00    5.877516    5.901750    5.945750    5.852500
# 2020-01-06 00:00:00+00:00    5.902165    5.926500    5.931750    5.781750
# 2020-01-07 00:00:00+00:00    5.973621    5.998250    6.044250    5.909750
# 2020-01-08 00:00:00+00:00    5.984825    6.009500    6.051000    5.953750
# ...                               ...         ...         ...         ...
# 2024-10-24 00:00:00+00:00  140.410004  140.410004  141.350006  138.460007
# 2024-10-25 00:00:00+00:00  141.539993  141.539993  144.130005  140.800003
# 2024-10-28 00:00:00+00:00  140.520004  140.520004  143.139999  140.050003
# 2024-10-29 00:00:00+00:00  141.250000  141.250000  142.259995  138.899994
# ...

# %%
SPXC =yf.download('SPXC', start, end)
SPXC
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                       Adj Close       Close        High         Low  \
# Ticker                           SPXC        SPXC        SPXC        SPXC
# Date
# 2020-01-02 00:00:00+00:00   50.790001   50.790001   51.450001   50.070000
# 2020-01-03 00:00:00+00:00   51.599998   51.599998   51.630001   50.090000
# 2020-01-06 00:00:00+00:00   51.169998   51.169998   51.259998   50.630001
# 2020-01-07 00:00:00+00:00   50.500000   50.500000   50.970001   50.040001
# 2020-01-08 00:00:00+00:00   49.799999   49.799999   50.869999   49.630001
# ...                               ...         ...         ...         ...
# 2024-10-24 00:00:00+00:00  157.520004  157.520004  158.289993  156.070007
# 2024-10-25 00:00:00+00:00  157.229996  157.229996  159.539993  156.429993
# 2024-10-28 00:00:00+00:00  159.899994  159.899994  161.220001  158.500000
# 2024-10-29 00:00:00+00:00  159.250000  159.250000  159.690002  157.259995
# ...

# %%
AMZN =yf.download('AMZN', start, end)
AMZN
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                       Adj Close       Close        High         Low  \
# Ticker                           AMZN        AMZN        AMZN        AMZN
# Date
# 2020-01-02 00:00:00+00:00   94.900497   94.900497   94.900497   93.207497
# 2020-01-03 00:00:00+00:00   93.748497   93.748497   94.309998   93.224998
# 2020-01-06 00:00:00+00:00   95.143997   95.143997   95.184502   93.000000
# 2020-01-07 00:00:00+00:00   95.343002   95.343002   95.694504   94.601997
# 2020-01-08 00:00:00+00:00   94.598503   94.598503   95.550003   94.321999
# ...                               ...         ...         ...         ...
# 2024-10-24 00:00:00+00:00  186.380005  186.380005  187.110001  183.860001
# 2024-10-25 00:00:00+00:00  187.830002  187.830002  190.449997  187.529999
# 2024-10-28 00:00:00+00:00  188.389999  188.389999  190.210007  188.210007
# 2024-10-29 00:00:00+00:00  190.830002  190.830002  191.460007  187.820007
# ...

# %%
AMZN =yf.download('AMZN', start, end)
AMZN.head() #showing top 5 rows
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                      Adj Close      Close       High        Low  \
# Ticker                          AMZN       AMZN       AMZN       AMZN
# Date
# 2020-01-02 00:00:00+00:00  94.900497  94.900497  94.900497  93.207497
# 2020-01-03 00:00:00+00:00  93.748497  93.748497  94.309998  93.224998
# 2020-01-06 00:00:00+00:00  95.143997  95.143997  95.184502  93.000000
# 2020-01-07 00:00:00+00:00  95.343002  95.343002  95.694504  94.601997
# 2020-01-08 00:00:00+00:00  94.598503  94.598503  95.550003  94.321999
#
# Price                           Open    Volume
# Ticker                          AMZN      AMZN
# Date
# 2020-01-02 00:00:00+00:00  93.750000  80580000
# 2020-01-03 00:00:00+00:00  93.224998  75288000
# 2020-01-06 00:00:00+00:00  93.000000  81236000
# 2020-01-07 00:00:00+00:00  95.224998  80898000
# 2020-01-08 00:00:00+00:00  94.902000  70160000

# %%
DIS =yf.download('DIS', start, end)
DIS.head() #showing top 5 rows
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                       Adj Close       Close        High         Low  \
# Ticker                            DIS         DIS         DIS         DIS
# Date
# 2020-01-02 00:00:00+00:00  147.040192  148.199997  148.199997  145.100006
# 2020-01-03 00:00:00+00:00  145.353500  146.500000  147.899994  146.050003
# 2020-01-06 00:00:00+00:00  144.510147  145.649994  146.029999  144.309998
# 2020-01-07 00:00:00+00:00  144.559753  145.699997  146.869995  145.419998
# 2020-01-08 00:00:00+00:00  144.262100  145.399994  146.130005  144.820007
#
# Price                            Open   Volume
# Ticker                            DIS      DIS
# Date
# 2020-01-02 00:00:00+00:00  145.289993  9502100
# 2020-01-03 00:00:00+00:00  146.399994  7320200
# 2020-01-06 00:00:00+00:00  145.539993  8262500
# 2020-01-07 00:00:00+00:00  145.990005  6906500
# 2020-01-08 00:00:00+00:00  145.490005  6984200

# %%
AAPL =yf.download('AAPL', start, end)
AAPL.head() #showing top 5 rows
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                      Adj Close      Close       High        Low  \
# Ticker                          AAPL       AAPL       AAPL       AAPL
# Date
# 2020-01-02 00:00:00+00:00  72.876106  75.087502  75.150002  73.797501
# 2020-01-03 00:00:00+00:00  72.167610  74.357498  75.144997  74.125000
# 2020-01-06 00:00:00+00:00  72.742645  74.949997  74.989998  73.187500
# 2020-01-07 00:00:00+00:00  72.400528  74.597504  75.224998  74.370003
# 2020-01-08 00:00:00+00:00  73.565193  75.797501  76.110001  74.290001
#
# Price                           Open     Volume
# Ticker                          AAPL       AAPL
# Date
# 2020-01-02 00:00:00+00:00  74.059998  135480400
# 2020-01-03 00:00:00+00:00  74.287498  146322800
# 2020-01-06 00:00:00+00:00  73.447502  118387200
# 2020-01-07 00:00:00+00:00  74.959999  108872000
# 2020-01-08 00:00:00+00:00  74.290001  132079200

# %%
bitcoin =yf.download('BIT=F', start, end)
bitcoin.head() #showing top 5 rows
# Out:
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BIT=F']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Empty DataFrame
# Columns: [(Adj Close, BIT=F), (Close, BIT=F), (High, BIT=F), (Low, BIT=F), (Open, BIT=F), (Volume, BIT=F)]
# Index: []

# %%
print('min price:', bitcoin['Adj Close'].min())
print('max price:', bitcoin['Adj Close'].max())
# Out:
# min price: Ticker
# BIT=F   NaN
# dtype: float64
# max price: Ticker
# BIT=F   NaN
# dtype: float64

# %%
print('min price:', AMZN['Adj Close'].min())
print('max price:', AMZN['Adj Close'].max())
# Out:
# min price: Ticker
# AMZN    81.82
# dtype: float64
# max price: Ticker
# AMZN    200.0
# dtype: float64

# %%
AMZN_price = AMZN[('Adj Close')]
AMZN_price.columns
# Out:
# Index(['AMZN'], dtype='object', name='Ticker')

# %%
min_index = AMZN['Adj Close'].idxmin() #min price
AMZN.loc[min_index]
# Out:
# Price                     Adj Close  Close       High        Low       Open  \
# Ticker                         AMZN   AMZN       AMZN       AMZN       AMZN
# Date
# 2022-12-28 00:00:00+00:00     81.82  81.82  83.480003  81.690002  82.800003
#
# Price                        Volume
# Ticker                         AMZN
# Date
# 2022-12-28 00:00:00+00:00  58228600

# %%
AMZN['Adj Close'].plot(label = 'bitcoin', figsize = (16,8))
# Out:
# <Axes: xlabel='Date'>

# %%
import matplotlib.pyplot as plt
AMZN['Adj Close'].plot(figsize = (16,8), color = 'g') #width, height
plt.xlabel('date')
plt.ylabel('price')
plt.title('bitcoin price')
# Out:
# Text(0.5, 1.0, 'bitcoin price')

# %%
tickers = ['META','AMZN','AAPL','NFLX','GOOG']
my_stock = yf.download(tickers , start ,end)
# Out:
# [*********************100%***********************]  5 of 5 completed

# %%
adj_close = my_stock['Adj Close']
adj_close.head()
# Out:
# Ticker                          AAPL       AMZN       GOOG        META  \
# Date
# 2020-01-02 00:00:00+00:00  72.876106  94.900497  68.201012  209.150269
# 2020-01-03 00:00:00+00:00  72.167610  93.748497  67.866325  208.043610
# 2020-01-06 00:00:00+00:00  72.742645  95.143997  69.539726  211.961823
# 2020-01-07 00:00:00+00:00  72.400528  95.343002  69.496330  212.420425
# 2020-01-08 00:00:00+00:00  73.565193  94.598503  70.043991  214.573944
#
# Ticker                           NFLX
# Date
# 2020-01-02 00:00:00+00:00  329.809998
# 2020-01-03 00:00:00+00:00  325.899994
# 2020-01-06 00:00:00+00:00  335.829987
# 2020-01-07 00:00:00+00:00  330.750000
# 2020-01-08 00:00:00+00:00  339.260010

# %%
my_stock['Adj Close'].plot(figsize = (16,8))
# Out:
# <Axes: xlabel='Date'>

# %%
my_stock['Adj Close'].pct_change().corr() #range; 1 and -1
# Out:
# Ticker      AAPL      AMZN      GOOG      META      NFLX
# Ticker
# AAPL    1.000000  0.597596  0.655933  0.563589  0.460648
# AMZN    0.597596  1.000000  0.653527  0.609845  0.541463
# GOOG    0.655933  0.653527  1.000000  0.646106  0.453168
# META    0.563589  0.609845  0.646106  1.000000  0.493284
# NFLX    0.460648  0.541463  0.453168  0.493284  1.000000

# %%
sns.heatmap(my_stock['Adj Close'].pct_change().corr(), annot = True)
# Out:
# <Axes: xlabel='Ticker', ylabel='Ticker'>
